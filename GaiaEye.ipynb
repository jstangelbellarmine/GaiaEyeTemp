# %% [markdown]
# <a href="https://colab.research.google.com/github/jstangelbellarmine/GaiaEyeTemp/blob/main/GaiaEye.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Basic Python utilities
import os
import numpy as np
import pandas as pd  # For handling data
import matplotlib.pyplot as plt  # For plotting graphs

# PyTorch (for deep learning models)
import torch

# OpenCV (for image processing)
import cv2

# Google Colab specific
from google.colab import drive  # For mounting Google Drive

# Ultralytics YOLO (if using YOLOv8)
try:
    import ultralytics
except ImportError:
    # !pip install ultralytics
    import ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 46.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 46.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 33.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 86.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/
# Out:
#  buckthornImg.jpg   GaiaEye.zip				 Steel_industry_data.csv   weather_2012.csv
# 'Colab Notebooks'  'March 2025 (6 Calendar Page).gdoc'	'Untitled document.gdoc'

# %%
# !unzip "/content/drive/MyDrive/GaiaEye.zip" -d "/content/"
# Out:
# Archive:  /content/drive/MyDrive/GaiaEye.zip
#    creating: /content/GaiaEye/
#   inflating: /content/GaiaEye/DesignArtifacts.html
#    creating: /content/GaiaEye/img/
#   inflating: /content/GaiaEye/img/aag.png
#   inflating: /content/GaiaEye/img/buckthorn.jpg
#   inflating: /content/GaiaEye/img/burnpile.png
#   inflating: /content/GaiaEye/img/dronecanopy.png
#   inflating: /content/GaiaEye/img/droneoveroak.webp
#   inflating: /content/GaiaEye/img/fire.jpg
#   inflating: /content/GaiaEye/img/honeysuckle.jpg
#   inflating: /content/GaiaEye/img/map.png
#   inflating: /content/GaiaEye/img/tree-of-heaven.jpg
#   inflating: /content/GaiaEye/LandingPage.html
#   inflating: /content/GaiaEye/New Text Document.txt
#   inflating: /content/GaiaEye/script.js
#   inflating: /content/GaiaEye/styles.css
#    creating: /content/GaiaEye/yolo/
#   inflating: /content/GaiaEye/yolo/classes.txt
#    creating: /content/GaiaEye/yolo/data/
#    creating: /content/GaiaEye/yolo/data/train/
# ...

# %%
# !ls /content/GaiaEye
# Out:
#  DesignArtifacts.html   LandingPage.html	 script.js    yolo
#  img		       'New Text Document.txt'	 styles.css

# %%
# !ls /content/GaiaEye/yolo
# Out:
# classes.txt  data  data.yaml  notes.json  train_val_split.py  yolo11s.pt

# %%
# !ls /content/GaiaEye/yolo/data
# Out:
# train  validation

# %%
# %cd /content/GaiaEye/yolo
# Out:
# /content/GaiaEye/yolo

# %%
# !ls /content/GaiaEye/yolo
# Out:
# classes.txt  data  data.yaml  notes.json  train_val_split.py  yolo11s.pt

# %%
# %%writefile /content/GaiaEye/yolo/requirements.txt
# ultralytics
# torch
# numpy
# pandas
# matplotlib
# opencv-python
# Out:
# Writing /content/GaiaEye/yolo/requirements.txt

# %%
# !pip install -r /content/GaiaEye/yolo/requirements.txt

# %%
import os
os.chdir('/content/GaiaEye/yolo')

# %%
# !ls
# Out:
# classes.txt  data  data.yaml  notes.json  requirements.txt  train_val_split.py	yolo11s.pt

# %%
# !pip install -r requirements.txt

# %%
import torch
import ultralytics
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from ultralytics import YOLO

model = YOLO('yolov8s.pt')
model.train(data="/content/GaiaEye/yolo/data.yaml", epochs=100, imgsz=640)
# Out:
# Ultralytics 8.3.95 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls /content/GaiaEye
# Out:
#  DesignArtifacts.html   LandingPage.html	 script.js    yolo
#  img		       'New Text Document.txt'	 styles.css

# %%
# !cat /content/GaiaEye/yolo/data.yaml
# Out:
# path: C:\Users\juani\Desktop\GaiaEye\yolo\data
# train: train/images
# val: validation/images
#
# nc: 1
# names: ["buckthorn"]

# %%
import yaml

# Path to your data.yaml file
yaml_path = "/content/GaiaEye/yolo/data.yaml"

# Load the YAML file
with open(yaml_path, "r") as file:
    data_config = yaml.safe_load(file)

# Fix the paths for Colab
data_config["path"] = "/content/GaiaEye/yolo/data"
data_config["train"] = "/content/GaiaEye/yolo/data/train/images"
data_config["val"] = "/content/GaiaEye/yolo/data/validation/images"

# Save the updated data.yaml
with open(yaml_path, "w") as file:
    yaml.dump(data_config, file)

print("✅ data.yaml has been updated successfully!")
# Out:
# ✅ data.yaml has been updated successfully!

# %%
# !cat /content/GaiaEye/yolo/data.yaml
# Out:
# names:
# - buckthorn
# nc: 1
# path: /content/GaiaEye/yolo/data
# train: /content/GaiaEye/yolo/data/train/images
# val: /content/GaiaEye/yolo/data/validation/images

# %%
# 1️⃣ MOUNT GOOGLE DRIVE
from google.colab import drive
drive.mount('/content/drive')

# 2️⃣ NAVIGATE TO PROJECT FOLDER & UNZIP IF NEEDED
import os

project_dir = "/content/GaiaEye"
if not os.path.exists(project_dir):
    # !unzip "/content/drive/MyDrive/GaiaEye.zip" -d "/content/"

# 3️⃣ INSTALL REQUIRED LIBRARIES
# !pip install ultralytics opencv-python-headless numpy torch torchvision torchaudio --quiet

# 4️⃣ CHECK DATASET FILES EXIST
# !ls /content/GaiaEye/yolo/data/train/images
# !ls /content/GaiaEye/yolo/data/validation/images
# !ls /content/GaiaEye/yolo/yolo11s.pt

# 5️⃣ OPTIMIZED TRAINING PARAMETERS
# !yolo train model=/content/GaiaEye/yolo/yolo11s.pt \
  data=/content/GaiaEye/yolo/data.yaml \
  epochs=100 imgsz=640 batch=32 \
  lr0=0.01 lrf=0.002 momentum=0.937 \
  warmup_epochs=5 warmup_momentum=0.8 warmup_bias_lr=0.1 \
  amp=True \
  hsv_h=0.015 hsv_s=0.7 hsv_v=0.4 \
  degrees=10 translate=0.2 scale=0.5 shear=2.0 perspective=0.0005 \
  flipud=0.5 fliplr=0.5 mosaic=1.0 mixup=0.1 \
  copy_paste=0.1 auto_augment=randaugment \
  weight_decay=0.0005 dropout=0.1
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 03c0d075-5560737-WEB_ChrisEvans_Invasive.org.jpg   660608cb-5456142.jpg
# 066c5551-1334023.jpg				   66334d34-1480383.jpg
# 07fc3852-5560738-WEB_ChrisEvans_Invasive.org.jpg   66c239a1-5468290.jpg
# 0b0da395-5456131.jpg				   66c74d7b-5456157.jpg
# 0d19db58-5468309.jpg				   6770b529-1480379.jpg
# 0f67d12b-5456112.jpg				   681c0d05-5456137.jpg
# 1085655a-5392494.jpg				   6bd32e0c-5456164.jpg
# 12a0a2ca-5392499.jpg				   6d199e5d-1480381.jpg
# 1310caae-5456143.jpg				   6d3c8623-5456106.jpg
# 13bcd8f3-5456154.jpg				   6e9a6716-5560735-WEB_ChrisEvans_Invasive.org.jpg
# 150d5f82-5456132.jpg				   6f592e2e-5456097.jpg
# 169a5109-5456163.jpg				   6f899f35-5456092.jpg
# 173490e0-5456168.jpg				   6fcdbd0f-1330017.jpg
# 185db02a-5476753.jpg				   7176c3a0-5456099.jpg
# 1998a449-5392495.jpg				   730c6710-5456121.jpg
# ...

# %%
# !ls /content/drive/MyDrive/
# Out:
#  buckthornImg.jpg   GaiaEye.zip				 Steel_industry_data.csv   weather_2012.csv
# 'Colab Notebooks'  'March 2025 (6 Calendar Page).gdoc'	'Untitled document.gdoc'

# %%
# !yolo predict model=runs/detect/train2/weights/best.pt source="/content/drive/MyDrive/buckthornImg.jpg" save=True
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/cfg/__init__.py", line 958, in entrypoint
#     model = YOLO(model, task=task)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/models/yolo/model.py", line 23, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py", line 148, in __init__
#     self._load(model, task=task)
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py", line 290, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py", line 1039, in attempt_load_one_weight
# ...

# %%
from IPython.display import display
from PIL import Image

image_path = "/content/runs/detect/predict/buckthornImg.jpg"  # Update if needed
display(Image.open(image_path))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-7a7ba01f21d7> in <cell line: 0>()
#       3
#       4 image_path = "/content/runs/detect/predict/buckthornImg.jpg"  # Update if needed
# ----> 5 display(Image.open(image_path))
#
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3463
#    3464     if filename:
# -> 3465         fp = builtins.open(filename, "rb")
#    3466         exclusive_fp = True
#    3467     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/runs/detect/predict/buckthornImg.jpg'

# %%
# !ls -R /content/runs/detect/

# %%
# !find /content/ -type d -name "predict"

# %%
# !ls /content/GaiaEye/yolo/runs/detect/predict/

# %%
from PIL import Image
from IPython.display import display

image_path = "/content/GaiaEye/yolo/runs/detect/predict/YOUR_IMAGE.jpg"  # Update with correct filename
display(Image.open(image_path))

# %%
# !ls /content/GaiaEye/yolo/runs/detect/

# %%
# !ls /content/GaiaEye/yolo/runs/detect/predict/

# %%
from PIL import Image
from IPython.display import display

image_path = "/content/GaiaEye/yolo/runs/detect/predict/buckthornImg.jpg"
display(Image.open(image_path))

# %%
# !yolo detect predict model=/content/GaiaEye/yolo/runs/detect/train2/weights/best.pt source="/content/drive/MyDrive/buckthornImg.jpg" imgsz=1280

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Path to the detected image (update if needed)
image_path = "/content/runs/detect/predict2/buckthornImg.jpg"

# Open and display image
img = Image.open(image_path)
plt.figure(figsize=(10, 10))  # Adjust figure size for better visibility
plt.imshow(img)
plt.axis("off")  # Hide axis
plt.show()

# %%
# !ls /content/runs/detect/predict2/

# %%
# !ls /content/runs/detect/
